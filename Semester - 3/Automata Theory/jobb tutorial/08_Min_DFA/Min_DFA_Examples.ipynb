# %% [markdown]
# # Notebook Overview
#
# ## IMPORTANT: I've added a "chatty" option that makes the algorithm describe itself!
#
# ### These are present in the Jove calls at the bottom of this notebook

# %% [markdown]
# ## Watch from the 1-min mark of the first video below and 34th-min mark of the second
#
# ### These videos were used in previous classes.

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import sys

# -- Detect if in Own Install or in Colab
try:
    import google.colab
    OWN_INSTALL = False
except:
    OWN_INSTALL = True
    
if OWN_INSTALL:
    
  #---- Leave these definitions ON if running on laptop
  #---- Else turn OFF by putting them between ''' ... '''

  sys.path[0:0] = ['../../../../..',  '../../../../../3rdparty',  
                   '../../../..',  '../../../../3rdparty',  
                   '../../..',     '../../../3rdparty', 
                   '../..',        '../../3rdparty',
                   '..',           '../3rdparty' ]

else: # In colab
  ! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
  sys.path.append('./Jove')
  sys.path.append('./Jove/jove')

# -- common imports --
from jove.DotBashers import *
from jove.Def_md2mc  import *
from jove.Def_DFA    import *
from jove.Def_NFA    import *
from jove.LangDef    import *  # for testing DFA actions
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Out:
# Cloning into 'Jove'...
# remote: Enumerating objects: 5485, done.
# remote: Counting objects: 100% (851/851), done.
# remote: Compressing objects: 100% (600/600), done.
# remote: Total 5485 (delta 446), reused 612 (delta 223), pack-reused 4634
# Receiving objects: 100% (5485/5485), 8.30 MiB | 15.63 MiB/s, done.
# Resolving deltas: 100% (3451/3451), done.
# You may use any of these help commands:
# help(ResetStNum)
# help(NxtStateStr)
#
# You may use any of these help commands:
# help(md2mc)
# .. and if you want to dig more, then ..
# help(default_line_attr)
# help(length_ok_input_items)
# help(union_line_attr_list_fld)
# help(extend_rsltdict)
# help(form_delta)
# help(get_machine_components)
#
# You may use any of these help commands:
# help(mkp_dfa)
# help(mk_dfa)
# help(totalize_dfa)
# help(addtosigma_delta)
# help(step_dfa)
# help(run_dfa)
# help(accepts_dfa)
# help(comp_dfa)
# help(union_dfa)
# help(intersect_dfa)
# help(pruneUnreach)
# help(iso_dfa)
# help(langeq_dfa)
# help(same_status)
# help(h_langeq_dfa)
# help(fixptDist)
# help(min_dfa)
# help(pairFR)
# help(state_combos)
# help(sepFinNonFin)
# help(bash_eql_classes)
# help(listminus)
# help(bash_1)
# help(mk_rep_eqc)
# help(F_of)
# help(rep_of_s)
# help(q0_of)
# help(Delta_of)
# help(mk_state_eqc_name)
#
# You may use any of these help commands:
# help(mk_nfa)
# help(totalize_nfa)
# help(step_nfa)
# help(run_nfa)
# help(ec_step_nfa)
# help(Eclosure)
# help(Echelp)
# help(accepts_nfa)
# help(nfa2dfa)
# help(n2d)
# help(inSets)
# help(rev_dfa)
# help(min_dfa_brz)
#
# You may use any of these help commands:
# help(lphi)
# help(lunit)
# help(lcat)
# help(lexp)
# help(lunion)
# help(lstar)
# help(srev)
# help(lrev)
# help(shomo)
# help(lhomo)
# help(powset)
# help(lint)
# help(lsymdiff)
# help(lminus)
# help(lissubset)
# help(lissuperset)
# help(lcomplem)
# help(product)
# help(nthnumeric)

# %% [markdown]
# # DFA Minimization
#
# This is a good juncture at which to introduce DFA minimization.

# %% [markdown]
# # Example DFA to minimize

# %% [markdown]
# ## Figure 6.7 (Page 74) from our Book

# %%
book_fig_67 = md2mc('''DFA

IS1 : a -> FS2
IS1 : b -> FS3

FS2 : a -> S4
FS2 : b -> S5   

FS3 : a -> S5
FS3 : b -> S4

S4 : a|b -> FS6

S5 : a|b -> FS6

FS6 : a|b -> FS6

''')
# Out:
# Generating LALR tables

# %% [markdown]
# # NEW: The chatty option makes the code execution apparent!

# %%
min_book_fig_67 = min_dfa(book_fig_67, chatty=True, state_name_mode='verbose')
# Out:
# Separating final and non-final states (marking 0-distinguishable entries).
#    The 0-distinguishable entries are:
# States  FS6  and  S4  are 0-distinguished.
# States  FS6  and  S5  are 0-distinguished.
# States  FS6  and  IS1  are 0-distinguished.
# States  S4  and  FS3  are 0-distinguished.
# States  S4  and  FS2  are 0-distinguished.
# States  S5  and  FS3  are 0-distinguished.
# States  S5  and  FS2  are 0-distinguished.
# States  FS3  and  IS1  are 0-distinguished.
# States  FS2  and  IS1  are 0-distinguished.
#
# Seeing if states  FS6  and  FS3  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  S5
#    Found a distinguishable pair!
#       Since  ('FS6', 'S5')  are  0  distinguishable, marking  ('FS6', 'FS3')  as  1  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  FS6  and  FS2  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  S4
#    Found a distinguishable pair!
#       Since  ('FS6', 'S4')  are  0  distinguishable, marking  ('FS6', 'FS2')  as  1  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  S4  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  FS6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  FS6  and  FS6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S4  and  IS1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  FS2
#    Found a distinguishable pair!
#       Since  ('FS6', 'FS2')  are  1  distinguishable, marking  ('S4', 'IS1')  as  2  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  S5  and  IS1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  FS2
#    Found a distinguishable pair!
#       Since  ('FS6', 'FS2')  are  1  distinguishable, marking  ('S5', 'IS1')  as  2  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  FS3  and  FS2  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S5  and  S4
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  S4  and  S5
#    Cannot distinguish yet, via  b
#
# Seeing if states  FS6  and  FS3  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  S5
#    The next states reached via symbol  b  are:  FS6  and  S4
#
# Seeing if states  FS6  and  FS2  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  S4
#    The next states reached via symbol  b  are:  FS6  and  S5
#
# Seeing if states  S4  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  FS6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  FS6  and  FS6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S4  and  IS1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  FS2
#    The next states reached via symbol  b  are:  FS6  and  FS3
#
# Seeing if states  S5  and  IS1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  FS6  and  FS2
#    The next states reached via symbol  b  are:  FS6  and  FS3
#
# Seeing if states  FS3  and  FS2  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S5  and  S4
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  S4  and  S5
#    Cannot distinguish yet, via  b
#
# Now, collecting equivalence-classes.
#    The equivalent pairs are:
#    The merged equivalent classes and representative states are these:
# State  FS3  represents the equivalent states  ['FS3', 'FS2']
# State  S5  represents the equivalent states  ['S5', 'S4']

# %%
dotObj_dfa(min_book_fig_67, STATENAME_MAXSIZE=20)

# %%
blimp = md2mc('''
DFA 
I1 : a -> F2
I1 : b -> F3
F2 : a -> S8
F2 : b -> S5
F3 : a -> S7
F3 : b -> S4
S4 : a | b -> F6
S5 : a | b -> F6
F6 : a | b -> F6
S7 : a | b -> F6
S8 : a -> F6
S8 : b -> F9
F9 : a -> F9
F9 : b -> F6
''')

# %%
help(dotObj_dfa)
# Out:
# Help on function dotObj_dfa in module jove.DotBashers:
#
# dotObj_dfa(D, FuseEdges=False, dfaName='do_', STATENAME_MAXSIZE=20)
#     In : D1 (DFA : partially consistent)
#          dfaName (string)
#          STATENAME_MAXSIZE : number
#     Out: A dot object.
#     Generate a dot object representing the automaton.
#     Suppress "black-hole states".

# %%
help(min_dfa)
# Out:
# Help on function min_dfa in module jove.Def_DFA:
#
# min_dfa(D, state_name_mode='succinct', chatty=False)
#     The top-level callable DFA minimizer.
#
#     In : D (consistent DFA to be minimized)
#     Out: Minimized version of D.
#
#     Given a DFA D, go through the state minimization algorithm.
#
#     Setting chatty=True helps reveal the detailed steps. Please try it!
#
#     If the state_name_mode is verbose, we will make state names
#     by stringing together the state names in the equivalence
#     classes. If 'succinct', then only the name of the equivalence-class
#     representative is retained.

# %% [markdown]
# # NEW: The chatty option makes the code execution apparent!

# %%
min_blimp = min_dfa(blimp, chatty=True, state_name_mode='verbose')
# Out:
# Separating final and non-final states (marking 0-distinguishable entries).
#    The 0-distinguishable entries are:
# States  S7  and  F3  are 0-distinguished.
# States  S7  and  F2  are 0-distinguished.
# States  S7  and  F9  are 0-distinguished.
# States  S7  and  F6  are 0-distinguished.
# States  S4  and  F3  are 0-distinguished.
# States  S4  and  F2  are 0-distinguished.
# States  S4  and  F9  are 0-distinguished.
# States  S4  and  F6  are 0-distinguished.
# States  F3  and  I1  are 0-distinguished.
# States  F3  and  S5  are 0-distinguished.
# States  F3  and  S8  are 0-distinguished.
# States  I1  and  F2  are 0-distinguished.
# States  I1  and  F9  are 0-distinguished.
# States  I1  and  F6  are 0-distinguished.
# States  F2  and  S5  are 0-distinguished.
# States  F2  and  S8  are 0-distinguished.
# States  S5  and  F9  are 0-distinguished.
# States  S5  and  F6  are 0-distinguished.
# States  S8  and  F9  are 0-distinguished.
# States  S8  and  F6  are 0-distinguished.
#
# Seeing if states  S7  and  S4  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S7  and  I1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F2
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  F6  and  F3
#    Cannot distinguish yet, via  b
#
# Seeing if states  S7  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S7  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F9
#    Cannot distinguish yet, via  b
#
# Seeing if states  S4  and  I1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F2
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  F6  and  F3
#    Cannot distinguish yet, via  b
#
# Seeing if states  S4  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S4  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F9
#    Cannot distinguish yet, via  b
#
# Seeing if states  F3  and  F2  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S7  and  S8
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  S4  and  S5
#    Cannot distinguish yet, via  b
#
# Seeing if states  F3  and  F9  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S7  and  F9
#    Found a distinguishable pair!
#       Since  ('S7', 'F9')  are  0  distinguishable, marking  ('F3', 'F9')  as  1  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  F3  and  F6  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S7  and  F6
#    Found a distinguishable pair!
#       Since  ('S7', 'F6')  are  0  distinguishable, marking  ('F3', 'F6')  as  1  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  I1  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F2  and  F6
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  F3  and  F6
#    Found a distinguishable pair!
#       Since  ('F3', 'F6')  are  1  distinguishable, marking  ('I1', 'S5')  as  2  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  I1  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F2  and  F6
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  F3  and  F9
#    Found a distinguishable pair!
#       Since  ('F3', 'F9')  are  1  distinguishable, marking  ('I1', 'S8')  as  2  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  F2  and  F9  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S8  and  F9
#    Found a distinguishable pair!
#       Since  ('S8', 'F9')  are  0  distinguishable, marking  ('F2', 'F9')  as  1  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  F2  and  F6  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S8  and  F6
#    Found a distinguishable pair!
#       Since  ('S8', 'F6')  are  0  distinguishable, marking  ('F2', 'F6')  as  1  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  S5  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F9
#    Cannot distinguish yet, via  b
#
# Seeing if states  F9  and  F6  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F9  and  F6
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S7  and  S4  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S7  and  I1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F2
#    Found a distinguishable pair!
#       Since  ('F6', 'F2')  are  1  distinguishable, marking  ('S7', 'I1')  as  2  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  S7  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S7  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F9
#    Cannot distinguish yet, via  b
#
# Seeing if states  S4  and  I1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F2
#    Found a distinguishable pair!
#       Since  ('F6', 'F2')  are  1  distinguishable, marking  ('S4', 'I1')  as  2  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  S4  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S4  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F9
#    Cannot distinguish yet, via  b
#
# Seeing if states  F3  and  F2  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S7  and  S8
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  S4  and  S5
#    Cannot distinguish yet, via  b
#
# Seeing if states  F3  and  F9  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S7  and  F9
#    The next states reached via symbol  b  are:  S4  and  F6
#
# Seeing if states  F3  and  F6  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S7  and  F6
#    The next states reached via symbol  b  are:  S4  and  F6
#
# Seeing if states  I1  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F2  and  F6
#    The next states reached via symbol  b  are:  F3  and  F6
#
# Seeing if states  I1  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F2  and  F6
#    The next states reached via symbol  b  are:  F3  and  F9
#
# Seeing if states  F2  and  F9  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S8  and  F9
#    The next states reached via symbol  b  are:  S5  and  F6
#
# Seeing if states  F2  and  F6  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S8  and  F6
#    The next states reached via symbol  b  are:  S5  and  F6
#
# Seeing if states  S5  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F9
#    Cannot distinguish yet, via  b
#
# Seeing if states  F9  and  F6  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F9  and  F6
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S7  and  S4  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S7  and  I1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F2
#    The next states reached via symbol  b  are:  F6  and  F3
#
# Seeing if states  S7  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S7  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F9
#    Cannot distinguish yet, via  b
#
# Seeing if states  S4  and  I1  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F2
#    The next states reached via symbol  b  are:  F6  and  F3
#
# Seeing if states  S4  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Seeing if states  S4  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F9
#    Cannot distinguish yet, via  b
#
# Seeing if states  F3  and  F2  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S7  and  S8
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  S4  and  S5
#    Cannot distinguish yet, via  b
#
# Seeing if states  F3  and  F9  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S7  and  F9
#    The next states reached via symbol  b  are:  S4  and  F6
#
# Seeing if states  F3  and  F6  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S7  and  F6
#    The next states reached via symbol  b  are:  S4  and  F6
#
# Seeing if states  I1  and  S5  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F2  and  F6
#    The next states reached via symbol  b  are:  F3  and  F6
#
# Seeing if states  I1  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F2  and  F6
#    The next states reached via symbol  b  are:  F3  and  F9
#
# Seeing if states  F2  and  F9  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S8  and  F9
#    The next states reached via symbol  b  are:  S5  and  F6
#
# Seeing if states  F2  and  F6  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  S8  and  F6
#    The next states reached via symbol  b  are:  S5  and  F6
#
# Seeing if states  S5  and  S8  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F6  and  F6
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#    The next states reached via symbol  b  are:  F6  and  F9
#    Cannot distinguish yet, via  b
#
# Seeing if states  F9  and  F6  can now be distinguished by any symbol.
#    The next states reached via symbol  a  are:  F9  and  F6
#    Cannot distinguish yet, via  a
#    The next states reached via symbol  b  are:  F6  and  F6
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#
# Now, collecting equivalence-classes.
#    The equivalent pairs are:
#    The merged equivalent classes and representative states are these:
# State  F6  represents the equivalent states  ['F6', 'F9']
# State  F3  represents the equivalent states  ['F3', 'F2']
# State  S5  represents the equivalent states  ['S5', 'S7', 'S8', 'S4']

# %%
dotObj_dfa(min_blimp, STATENAME_MAXSIZE=20)

# %%
ADFA = md2mc('''DFA

I : a -> A
I : b -> B

A : a -> A
A : b -> C   

B : a -> A
B : b -> B

C : a -> A
C : b -> F

F : a -> A
F : b -> B

''')

# %%
print(ADFA)
# Out:
# {'Q': {'I', 'A', 'C', 'F', 'B'}, 'Sigma': {'b', 'a'}, 'Delta': {('I', 'a'): 'A', ('I', 'b'): 'B', ('A', 'a'): 'A', ('A', 'b'): 'C', ('B', 'a'): 'A', ('B', 'b'): 'B', ('C', 'a'): 'A', ('C', 'b'): 'F', ('F', 'a'): 'A', ('F', 'b'): 'B'}, 'q0': 'I', 'F': {'F'}}

# %%
dotObj_dfa(ADFA)

# %%
minADFA = min_dfa(ADFA, chatty=True, state_name_mode='verbose')
# Out:
# Separating final and non-final states (marking 0-distinguishable entries).
#    The 0-distinguishable entries are:
# States  I  and  F  are 0-distinguished.
# States  A  and  F  are 0-distinguished.
# States  C  and  F  are 0-distinguished.
# States  F  and  B  are 0-distinguished.
#
# Seeing if states  I  and  A  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  B  and  C
#    Cannot distinguish yet, via  b
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  I  and  C  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  B  and  F
#    Found a distinguishable pair!
#       Since  ('B', 'F')  are  0  distinguishable, marking  ('I', 'C')  as  1  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  I  and  B  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  B  and  B
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  A  and  C  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  C  and  F
#    Found a distinguishable pair!
#       Since  ('C', 'F')  are  0  distinguishable, marking  ('A', 'C')  as  1  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  A  and  B  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  C  and  B
#    Cannot distinguish yet, via  b
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  C  and  B  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  F  and  B
#    Found a distinguishable pair!
#       Since  ('F', 'B')  are  0  distinguishable, marking  ('C', 'B')  as  1  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  I  and  A  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  B  and  C
#    Found a distinguishable pair!
#       Since  ('B', 'C')  are  1  distinguishable, marking  ('I', 'A')  as  2  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  I  and  C  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  B  and  F
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  I  and  B  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  B  and  B
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  A  and  C  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  C  and  F
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  A  and  B  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  C  and  B
#    Found a distinguishable pair!
#       Since  ('C', 'B')  are  1  distinguishable, marking  ('A', 'B')  as  2  distinguishable.
#          Hence, must continue through one more sweep of the algorithm.
#
# Seeing if states  C  and  B  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  F  and  B
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  I  and  A  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  B  and  C
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  I  and  C  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  B  and  F
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  I  and  B  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  B  and  B
#       Nope. Symbol  b  could not distinguish (the next states are the same).
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  A  and  C  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  C  and  F
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  A  and  B  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  C  and  B
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Seeing if states  C  and  B  can now be distinguished by any symbol.
#    The next states reached via symbol  b  are:  F  and  B
#    The next states reached via symbol  a  are:  A  and  A
#       Nope. Symbol  a  could not distinguish (the next states are the same).
#
# Now, collecting equivalence-classes.
#    The equivalent pairs are:
#    The merged equivalent classes and representative states are these:
# State  I  represents the equivalent states  ['I', 'B']

# %%
dotObj_dfa(minADFA, STATENAME_MAXSIZE=20)

# %%
DFA2 = md2mc('''DFA

I : a -> A
I : b -> I

A : a -> A
A : b -> F

F : a|b -> F   

''')

# %%
dotObj_dfa(DFA2,FuseEdges=True)
